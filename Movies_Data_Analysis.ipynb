# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Upload the movie data files

# %%
## Upload the movies csv dataset with no titles
movies = pd.read_csv('movie_rating_dataset_no_titles.csv', header=None)
print(movies.head())
# Out:
#         0                            1         2  \
# 0   19404  Dilwale Dulhania Le Jayenge  10/20/95
# 1     278     The Shawshank Redemption   9/23/94
# 2     238                The Godfather   3/14/72
# 3  724089    Gabriel's Inferno Part II   7/31/20
# 4     424             Schindler's List  11/30/93
#
#                                                    3       4
# 0  Raj is a rich, carefree, happy-go-lucky second...  25.884
# 1  Framed in the 1940s for the double murder of h...  60.110
# 2  Spanning the years 1945 to 1955, a chronicle o...  62.784
# 3  Professor Gabriel Emerson finally learns the t...  28.316
# 4  The true story of how businessman Oskar Schind...  38.661

# %% [markdown]
# ## Add column headers to the movies datafile

# %%
# Add column headers
movies.columns = ['ID','Title','Release_Date', 'Overview', 'Popularity']
print(movies.head())
# Out:
#        ID                        Title Release_Date  \
# 0   19404  Dilwale Dulhania Le Jayenge     10/20/95
# 1     278     The Shawshank Redemption      9/23/94
# 2     238                The Godfather      3/14/72
# 3  724089    Gabriel's Inferno Part II      7/31/20
# 4     424             Schindler's List     11/30/93
#
#                                             Overview  Popularity
# 0  Raj is a rich, carefree, happy-go-lucky second...      25.884
# 1  Framed in the 1940s for the double murder of h...      60.110
# 2  Spanning the years 1945 to 1955, a chronicle o...      62.784
# 3  Professor Gabriel Emerson finally learns the t...      28.316
# 4  The true story of how businessman Oskar Schind...      38.661

# %% [markdown]
# ## Upload the Ratings data file

# %%
#Upload the Ratings dataset with no titles
ratings = pd.read_csv('movie_ratings_dataset_2_no_titles.csv', header=None)
print(ratings.head())
# Out:
#         0    1      2      3
# 0   19404  8.7   3304  False
# 1     278  8.7  20369  False
# 2     238  8.7  15219  False
# 3  724089  8.6   1360  False
# 4     424  8.6  12158  False

# %% [markdown]
# ## Add column headers to the Ratings data file

# %%
# Add column headers
ratings.columns = ['ID', 'Vote_Average', 'Vote_Count', 'Video']
print(ratings.head())
# Out:
#        ID  Vote_Average  Vote_Count  Video
# 0   19404           8.7        3304  False
# 1     278           8.7       20369  False
# 2     238           8.7       15219  False
# 3  724089           8.6        1360  False
# 4     424           8.6       12158  False

# %% [markdown]
# ## Combine the data files into one dataframe

# %%
# Merge the datasets into one dataset
data = pd.merge(movies, ratings, on =['ID','ID'])
print(data.head())
# Out:
#        ID                        Title Release_Date  \
# 0   19404  Dilwale Dulhania Le Jayenge     10/20/95
# 1     278     The Shawshank Redemption      9/23/94
# 2     238                The Godfather      3/14/72
# 3  724089    Gabriel's Inferno Part II      7/31/20
# 4     424             Schindler's List     11/30/93
#
#                                             Overview  Popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...      25.884
# 1  Framed in the 1940s for the double murder of h...      60.110
# 2  Spanning the years 1945 to 1955, a chronicle o...      62.784
# 3  Professor Gabriel Emerson finally learns the t...      28.316
# 4  The true story of how businessman Oskar Schind...      38.661
#
#    Vote_Average  Vote_Count  Video
# 0           8.7        3304  False
# 1           8.7       20369  False
# 2           8.7       15219  False
# 3           8.6        1360  False
# 4           8.6       12158  False

# %%
# Look at the info for the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9463 entries, 0 to 9462
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            9463 non-null   int64
#  1   Title         9463 non-null   object
#  2   Release_Date  9463 non-null   object
#  3   Overview      9449 non-null   object
#  4   Popularity    9463 non-null   float64
#  5   Vote_Average  9463 non-null   float64
#  6   Vote_Count    9463 non-null   int64
#  7   Video         9463 non-null   bool
# dtypes: bool(1), float64(2), int64(2), object(3)
# memory usage: 858.7+ KB

# %% [markdown]
# ## Check for any inconsistencies

# %%
# Here we see we have a dataframe with 8 columns and 9463 rows.

# %%
# Look for missing values
data.isnull().sum()
# Out:
# ID               0
# Title            0
# Release_Date     0
# Overview        14
# Popularity       0
# Vote_Average     0
# Vote_Count       0
# Video            0
# dtype: int64

# %%
# Pull the rows with missing values in the Overview column
data[data.isna().any(axis=1)]
# Out:
#           ID                             Title Release_Date Overview  \
# 3974   38537                      Nati stanchi       3/1/02      NaN
# 4091   53957                        La matassa      3/13/09      NaN
# 5497   26285            Fantozzi Still Suffers       1/1/83      NaN
# 6101   79643      Anche se è amore non si vede     11/23/11      NaN
# 6369   31359             Would I Lie to You? 2       2/7/01      NaN
# 7314    2029                            Tanguy     11/21/01      NaN
# 8691   17413                         Incognito      4/28/09      NaN
# 8864  516043                   Arrivano i prof       5/1/18      NaN
# 8973  154512                  Lightning Strike     12/13/12      NaN
# 9222  408238  The New Adventures of Cinderella     10/18/17      NaN
# 9229   42436                Natale in crociera     12/14/07      NaN
# 9240   85056       Vacanze di Natale a Cortina     12/16/11      NaN
# 9326  244514                  Colpi di fortuna     12/21/13      NaN
# ...

# %%
# I am ok with theses rows staying in the dataframe because the Overview column is of low importance. 
# If it was important, I would either fill it in if the information was available or remove the rows from the dataset.

# %%
# Take a look at the distribution of the ratings
import plotly.express as px
fig = px.histogram(data, 'Vote_Average')
fig.show()

# %%
## Take a look at the top 10 movies by rating
data.nlargest(n=10, columns=['Vote_Average'])
# Out:
#        ID                                   Title Release_Date  \
# 0   19404             Dilwale Dulhania Le Jayenge     10/20/95
# 1     278                The Shawshank Redemption      9/23/94
# 2     238                           The Godfather      3/14/72
# 3  724089               Gabriel's Inferno Part II      7/31/20
# 4     424                        Schindler's List     11/30/93
# 5  696374                       Gabriel's Inferno      5/29/20
# 6  761053              Gabriel's Inferno Part III     11/19/20
# 7     240                  The Godfather: Part II     12/20/74
# 8  283566  Evangelion: 3.0+1.0 Thrice Upon a Time       3/8/21
# 9  255709                                    Hope      10/2/13
#
#                                             Overview  Popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...      25.884
# 1  Framed in the 1940s for the double murder of h...      60.110
# 2  Spanning the years 1945 to 1955, a chronicle o...      62.784
# ...

# %%
## Take a look at the bottom 10 movies by rating
data.nsmallest(n=10, columns=['Vote_Average'])
# Out:
#           ID                                   Title Release_Date  \
# 9462   40016              Birdemic: Shock and Terror      2/27/10
# 9461   14164                    Dragonball Evolution      3/12/09
# 9457   12142                       Alone in the Dark      1/28/05
# 9458   13805                          Disaster Movie      8/29/08
# 9459    5491                       Battlefield Earth      5/12/00
# 9460   11059                       House of the Dead      4/11/03
# 9456   74849           The Star Wars Holiday Special      12/1/78
# 9450   94365  The Human Centipede 3 (Final Sequence)      5/22/15
# 9451  160070                       Apartment 1303 3D      12/6/12
# 9452    9544                              FearDotCom       8/9/02
#
#                                                Overview  Popularity  \
# 9462  A platoon of eagles and vultures attacks the r...       7.341
# 9461  The young warrior Son Goku sets out on a quest...      52.129
# ...
