# %%
import pandas as pd

url = "https://nc-aftermarket-www-production.s3.amazonaws.com/reports/Namecheap_Market_Sales.csv"

df = pd.read_csv(url)

# %%
df.head()
# Out:
#                                                  url                 name  \
# 0  https://www.namecheap.com/market/sale/xgXPCMcF...  bitcoin.contractors
# 1  https://www.namecheap.com/market/sale/abdZTtAo...              nft.vet
# 2  https://www.namecheap.com/market/sale/tFH35tkN...              ian.xyz
# 3  https://www.namecheap.com/market/sale/u1kZEchX...             iwin.fun
# 4  https://www.namecheap.com/market/sale/uUFWB9Yo...            with.fund
#
#                   startDate                   endDate  price  startPrice  \
# 0  2024-03-15T23:30:00.000Z  2024-03-31T16:00:00.000Z   15.0          15
# 1  2024-03-13T23:30:00.000Z  2024-03-29T16:00:00.000Z   15.0          15
# 2  2024-03-09T23:30:00.000Z  2024-03-25T16:00:00.000Z   15.0          15
# 3  2024-03-11T23:30:00.000Z  2024-03-27T16:00:00.000Z   15.0          15
# 4  2024-03-14T23:30:00.000Z  2024-03-30T16:00:00.000Z   15.0          15
#
#    renewPrice  bidCount  ahrefsDomainRating  alexaRanking  umbrellaRanking  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345703 entries, 0 to 345702
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   url                 345703 non-null  object
#  1   name                345703 non-null  object
#  2   startDate           345703 non-null  object
#  3   endDate             345703 non-null  object
#  4   price               345703 non-null  float64
#  5   startPrice          345703 non-null  int64
#  6   renewPrice          345703 non-null  float64
#  7   bidCount            345703 non-null  int64
#  8   ahrefsDomainRating  345703 non-null  int64
#  9   alexaRanking        0 non-null       float64
#  10  umbrellaRanking     0 non-null       float64
#  11  backlinksCount      345703 non-null  int64
#  12  cloudflareRanking   320 non-null     float64
#  13  estibotValue        345703 non-null  int64
#  14  extensionsTaken     345703 non-null  int64
# ...
